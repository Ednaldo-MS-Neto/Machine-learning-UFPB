# %% [markdown]
# # Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

import sklearn
import random

from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier

from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

#utils
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier,MLPRegressor
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Importação dos dados

# %%
def read_instance(filepath):
    data = pd.read_csv(filepath)
    return(data)

# %%
data = read_instance('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# # Exploração inicial dos dados

# %%
mulher = data.loc[data.Sex == 'female']["Survived"]
m_sobrevivente = sum(mulher)/len(mulher)

print("% de mulheres sobreviventes:", m_sobrevivente )

homem = data.loc[data.Sex == 'male']["Survived"]
h_sobrevivente = sum(homem)/len(homem)

print("% de mulheres sobreviventes:", h_sobrevivente )

sns.barplot(x="Sex", y="Survived", data=data);
# Out:
# % de mulheres sobreviventes: 0.7420382165605095
# % de mulheres sobreviventes: 0.18890814558058924

# %%
sns.barplot(x="Pclass", y="Survived", data=data);

# %%
sns.barplot(x="Embarked", y="Survived", data=data);

# %%
sns.barplot(x="SibSp", y="Survived", data=data);

# %%
sns.barplot(x="Parch", y="Survived", data=data);

# %%
data["Age"] = data["Age"].fillna(0)
bins = [-1, 0, 12, 18, 25, 45, np.inf]
labels = ['-1', 'bebe', 'criança', 'adolecente', 'adulto', 'velho']
data['Grupo idade'] = pd.cut(data["Age"], bins, labels = labels)

sns.barplot(x="Grupo idade", y="Survived", data=data)
plt.show()

# %% [markdown]
# # Limpeza dos dados

# %% [markdown]
# A função *clean_data* executa a seguintes ações:
# 1. Drop das colunas Name, Ticket, SibSp, Embarked, Cabin, PassagerId, Fare
# 2. Preenche os dados faltantes da coluna de idade com a média das idades
# 3. Transforma a coluna de idades em uma coluna de inteiros
# 4. Se houver dropa todos os NA(não há)
# 5. Troca o valor da colna Sex por 1 quando homem e 0 quando mulher

# %%
def clean_data(data):
    #data = read_instance(data)
    #retirando a coluna de nomes, local de embarque, tarifa do passageiro, numero da cabine
    #numero do ticket 
    data = data.drop(columns=['Name'])
    data = data.drop(columns=['Ticket'])
    data = data.drop(columns=['SibSp'])
    data = data.drop(columns=['Embarked'])
    data = data.drop(columns=['Cabin'])
    data = data.drop(columns=['PassengerId'])
    data = data.drop(columns=['Fare'])
    
    media_age = data.Age.median()
    data.fillna(media_age, inplace = True)
    
    data["Age"] = data["Age"].astype(int)
  
    data = data.dropna()
    #trocando valores de male e female por 1 e 0
    data.loc[data.Sex=='male','Sex'] = 1
    data.loc[data.Sex=='female','Sex'] = 0
    return data

# %%
data = read_instance('train.csv')

# %% [markdown]
# A matriz de correlação mostra uma alta correlação entre(0.41) as colunas Parch e SisbSp, e uma alta correlação inversa(-055) entre PClass e Fare dessa forma escolhi manter apenas Parch e PClass

# %%
sns.heatmap(data.corr(), annot = True);

# %%
data = clean_data(data)
data
# Out:
#      Survived  Pclass Sex  Age  Parch
# 0           0       3   1   22      0
# 1           1       1   0   38      0
# 2           1       3   0   26      0
# 3           1       1   0   35      0
# 4           0       3   1   35      0
# ..        ...     ...  ..  ...    ...
# 886         0       2   1   27      0
# 887         1       1   0   19      0
# 888         0       3   0   28      2
# 889         1       1   1   26      0
# 890         0       3   1   32      0
#
# [891 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    int32
#  4   Parch     891 non-null    int64
# dtypes: int32(1), int64(3), object(1)
# memory usage: 38.3+ KB

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       Parch
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.345679    0.381594
# std      0.486592    0.836071   13.028212    0.806057
# min      0.000000    1.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000
# 50%      0.000000    3.000000   28.000000    0.000000
# 75%      1.000000    3.000000   35.000000    0.000000
# max      1.000000    3.000000   80.000000    6.000000

# %%
data.shape
# Out:
# (891, 5)

# %% [markdown]
# # Criação e normalização treino e teste

# %%
x,y = data.drop(columns=['Survived']), data['Survived']

# %%
x
# Out:
#      Pclass Sex  Age  Parch
# 0         3   1   22      0
# 1         1   0   38      0
# 2         3   0   26      0
# 3         1   0   35      0
# 4         3   1   35      0
# ..      ...  ..  ...    ...
# 886       2   1   27      0
# 887       1   0   19      0
# 888       3   0   28      2
# 889       1   1   26      0
# 890       3   1   32      0
#
# [891 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# ### Normalização

# %% [markdown]
# Normalização por causa dos grandes valores da coluna idade, não é necessário normalizar y pois ele já está entre 0 e 1

# %%
scaler = MinMaxScaler() # padrão (0,1)
X_scaled = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(X_scaled,y, test_size=0.2)

# %%
print("Shape X_train: ",x_train.shape)
print("Shape y_train: ",y_train.shape)
# Out:
# Shape X_train:  (712, 4)
# Shape y_train:  (712,)

# %%
print("Shape X_test: ",x_test.shape)
print("Shape y_test: ",y_test.shape)
# Out:
# Shape X_test:  (179, 4)
# Shape y_test:  (179,)

# %%
x_train
# Out:
# array([[1.        , 1.        , 0.35      , 0.        ],
#        [1.        , 0.        , 0.0375    , 0.16666667],
#        [0.5       , 0.        , 0.35      , 0.        ],
#        ...,
#        [1.        , 1.        , 0.35      , 0.16666667],
#        [0.5       , 0.        , 0.5       , 0.16666667],
#        [1.        , 1.        , 0.5       , 0.16666667]])

# %% [markdown]
# #  Implementação do modelo baseado em Rede Neural

# %% [markdown]
# A arquitetura escolhida iria ser 12 neuronios em camada única por causa do número de exemplos passados o objetivo era ter 71(712/10) parametros no modelo por conta da regra de ouro

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=10, activation='relu', input_shape = (4, )))
model.add(tf.keras.layers.Dropout(0.05))
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# Escolhi a função sigmoid como função de saida pois era uma saida binaria entre 0 e 1

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 61
# Trainable params: 61
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer='Adam', loss='BinaryCrossentropy', metrics = ['BinaryAccuracy'])
epochs_hist = model.fit(x_train, y_train, epochs = 100, validation_split = 0.2)
y_pred = model.predict(x_test)

y_pred = (y_pred > 0.5)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 11ms/step - loss: 0.7366 - binary_accuracy: 0.3866 - val_loss: 0.7146 - val_binary_accuracy: 0.4965
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7197 - binary_accuracy: 0.3831 - val_loss: 0.7020 - val_binary_accuracy: 0.4825
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7062 - binary_accuracy: 0.3708 - val_loss: 0.6936 - val_binary_accuracy: 0.4685
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6947 - binary_accuracy: 0.4552 - val_loss: 0.6874 - val_binary_accuracy: 0.5035
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6862 - binary_accuracy: 0.5852 - val_loss: 0.6818 - val_binary_accuracy: 0.6084
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.
# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
print("ein =", 1-epochs_hist.history['binary_accuracy'][-1])
print("eout =", 1-accuracy_score(y_test,y_pred))
# Out:
# ein = 0.19156414270401
# eout = 0.16759776536312854

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss','Val Loss']);

# %%
plt.plot(epochs_hist.history['binary_accuracy'])
plt.plot(epochs_hist.history['val_binary_accuracy'])

plt.title('Model accuracy Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation accuracy')
plt.legend(['Training accuracy','Val accuracy']);

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       120
#            1       0.77      0.69      0.73        59
#
#     accuracy                           0.83       179
#    macro avg       0.82      0.80      0.81       179
# weighted avg       0.83      0.83      0.83       179

# %% [markdown]
# ## Modelo extrapolado(titulo de curiosidade para verificar underfitting)

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=30, activation='relu', input_shape=(4, )))
model.add(tf.keras.layers.Dense(units=40, activation='relu'))
model.add(tf.keras.layers.Dense(units=40, activation='relu'))
model.add(tf.keras.layers.Dense(units=30, activation='relu'))

model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
print(model.summary())

model.compile(optimizer='Adam', loss='BinaryCrossentropy', metrics = ['BinaryAccuracy'])
epochs_hist = model.fit(x_train, y_train, epochs = 300, validation_split = 0.2)
y_pred = model.predict(x_test)
#uso da sigmoid, poderias usar o round
y_pred = (y_pred > 0.5)
print("ein =", 1-epochs_hist.history['binary_accuracy'][-1])
print("eout =", 1-accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 30)                150
#
#  dense_3 (Dense)             (None, 40)                1240
#
#  dense_4 (Dense)             (None, 40)                1640
#
#  dense_5 (Dense)             (None, 30)                1230
#
#  dense_6 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 4,291
# Trainable params: 4,291
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 18/18 [==============================] - 1s 9ms/step - loss: 0.6506 - binary_accuracy: 0.6274 - val_loss: 0.6395 - val_binary_accuracy: 0.5594
# Epoch 2/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5906 - binary_accuracy: 0.6362 - val_loss: 0.6100 - val_binary_accuracy: 0.6503
# Epoch 3/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5475 - binary_accuracy: 0.7610 - val_loss: 0.5837 - val_binary_accuracy: 0.7413
# Epoch 4/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5169 - binary_accuracy: 0.7856 - val_loss: 0.5645 - val_binary_accuracy: 0.7413
# Epoch 5/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4980 - binary_accuracy: 0.7856 - val_loss: 0.5533 - val_binary_accuracy: 0.7413
# Epoch 6/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4828 - binary_accuracy: 0.7856 - val_loss: 0.5408 - val_binary_accuracy: 0.7273
# Epoch 7/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4715 - binary_accuracy: 0.7856 - val_loss: 0.5355 - val_binary_accuracy: 0.7413
# Epoch 8/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4656 - binary_accuracy: 0.7856 - val_loss: 0.5334 - val_binary_accuracy: 0.7273
# Epoch 9/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4587 - binary_accuracy: 0.7961 - val_loss: 0.5302 - val_binary_accuracy: 0.7273
# Epoch 10/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4514 - binary_accuracy: 0.7856 - val_loss: 0.5286 - val_binary_accuracy: 0.7273
# Epoch 11/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4483 - binary_accuracy: 0.8084 - val_loss: 0.5322 - val_binary_accuracy: 0.7203
# Epoch 12/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4467 - binary_accuracy: 0.7979 - val_loss: 0.5263 - val_binary_accuracy: 0.7343
# Epoch 13/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4449 - binary_accuracy: 0.8102 - val_loss: 0.5328 - val_binary_accuracy: 0.7343
# Epoch 14/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4379 - binary_accuracy: 0.8120 - val_loss: 0.5301 - val_binary_accuracy: 0.7343
# Epoch 15/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4345 - binary_accuracy: 0.8137 - val_loss: 0.5259 - val_binary_accuracy: 0.7273
# Epoch 16/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4327 - binary_accuracy: 0.8190 - val_loss: 0.5254 - val_binary_accuracy: 0.7343
# Epoch 17/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4329 - binary_accuracy: 0.8207 - val_loss: 0.5250 - val_binary_accuracy: 0.7343
# Epoch 18/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4283 - binary_accuracy: 0.8207 - val_loss: 0.5270 - val_binary_accuracy: 0.7273
# Epoch 19/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4312 - binary_accuracy: 0.8155 - val_loss: 0.5287 - val_binary_accuracy: 0.7343
# Epoch 20/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4265 - binary_accuracy: 0.8207 - val_loss: 0.5210 - val_binary_accuracy: 0.7273
# Epoch 21/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4242 - binary_accuracy: 0.8190 - val_loss: 0.5255 - val_binary_accuracy: 0.7343
# Epoch 22/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4282 - binary_accuracy: 0.8120 - val_loss: 0.5219 - val_binary_accuracy: 0.7413
# Epoch 23/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4297 - binary_accuracy: 0.7961 - val_loss: 0.5205 - val_binary_accuracy: 0.7413
# Epoch 24/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4247 - binary_accuracy: 0.8190 - val_loss: 0.5294 - val_binary_accuracy: 0.7413
# Epoch 25/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4228 - binary_accuracy: 0.8084 - val_loss: 0.5181 - val_binary_accuracy: 0.7413
# Epoch 26/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4243 - binary_accuracy: 0.8120 - val_loss: 0.5150 - val_binary_accuracy: 0.7413
# Epoch 27/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4190 - binary_accuracy: 0.8172 - val_loss: 0.5196 - val_binary_accuracy: 0.7413
# Epoch 28/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4191 - binary_accuracy: 0.8172 - val_loss: 0.5167 - val_binary_accuracy: 0.7483
# Epoch 29/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4162 - binary_accuracy: 0.8225 - val_loss: 0.5129 - val_binary_accuracy: 0.7483
# Epoch 30/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4180 - binary_accuracy: 0.8172 - val_loss: 0.5154 - val_binary_accuracy: 0.7483
# Epoch 31/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4162 - binary_accuracy: 0.8137 - val_loss: 0.5145 - val_binary_accuracy: 0.7343
# Epoch 32/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4175 - binary_accuracy: 0.8120 - val_loss: 0.5280 - val_binary_accuracy: 0.7413
# Epoch 33/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4164 - binary_accuracy: 0.8137 - val_loss: 0.5176 - val_binary_accuracy: 0.7343
# Epoch 34/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4153 - binary_accuracy: 0.8155 - val_loss: 0.5220 - val_binary_accuracy: 0.7483
# Epoch 35/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4113 - binary_accuracy: 0.8207 - val_loss: 0.5190 - val_binary_accuracy: 0.7413
# Epoch 36/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4133 - binary_accuracy: 0.8190 - val_loss: 0.5169 - val_binary_accuracy: 0.7413
# Epoch 37/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4123 - binary_accuracy: 0.8207 - val_loss: 0.5157 - val_binary_accuracy: 0.7343
# Epoch 38/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4108 - binary_accuracy: 0.8172 - val_loss: 0.5220 - val_binary_accuracy: 0.7552
# Epoch 39/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4164 - binary_accuracy: 0.8032 - val_loss: 0.5177 - val_binary_accuracy: 0.7483
# Epoch 40/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4100 - binary_accuracy: 0.8243 - val_loss: 0.5217 - val_binary_accuracy: 0.7413
# Epoch 41/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.
300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3871 - binary_accuracy: 0.8366 - val_loss: 0.5508 - val_binary_accuracy: 0.7552
# Epoch 96/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3908 - binary_accuracy: 0.8313 - val_loss: 0.5490 - val_binary_accuracy: 0.7622
# Epoch 97/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3910 - binary_accuracy: 0.8348 - val_loss: 0.5649 - val_binary_accuracy: 0.7483
# Epoch 98/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3907 - binary_accuracy: 0.8348 - val_loss: 0.5523 - val_binary_accuracy: 0.7622
# Epoch 99/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3920 - binary_accuracy: 0.8383 - val_loss: 0.5593 - val_binary_accuracy: 0.7552
# Epoch 100/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3889 - binary_accuracy: 0.8348 - val_loss: 0.5586 - val_binary_accuracy: 0.7552
# Epoch 101/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3879 - binary_accuracy: 0.8330 - val_loss: 0.5583 - val_binary_accuracy: 0.7622
# Epoch 102/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3888 - binary_accuracy: 0.8366 - val_loss: 0.5582 - val_binary_accuracy: 0.7552
# Epoch 103/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3928 - binary_accuracy: 0.8278 - val_loss: 0.5571 - val_binary_accuracy: 0.7622
# Epoch 104/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3923 - binary_accuracy: 0.8330 - val_loss: 0.5621 - val_binary_accuracy: 0.7483
# Epoch 105/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3880 - binary_accuracy: 0.8383 - val_loss: 0.5550 - val_binary_accuracy: 0.7552
# Epoch 106/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3898 - binary_accuracy: 0.8418 - val_loss: 0.5653 - val_binary_accuracy: 0.7483
# Epoch 107/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3907 - binary_accuracy: 0.8313 - val_loss: 0.5609 - val_binary_accuracy: 0.7622
# Epoch 108/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3878 - binary_accuracy: 0.8348 - val_loss: 0.5632 - val_binary_accuracy: 0.7552
# Epoch 109/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3890 - binary_accuracy: 0.8383 - val_loss: 0.5556 - val_binary_accuracy: 0.7552
# Epoch 110/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3866 - binary_accuracy: 0.8366 - val_loss: 0.5644 - val_binary_accuracy: 0.7622
# Epoch 111/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3864 - binary_accuracy: 0.8383 - val_loss: 0.5622 - val_binary_accuracy: 0.7552
# Epoch 112/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3877 - binary_accuracy: 0.8348 - val_loss: 0.5623 - val_binary_accuracy: 0.7622
# Epoch 113/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3852 - binary_accuracy: 0.8383 - val_loss: 0.5646 - val_binary_accuracy: 0.7552
# Epoch 114/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3874 - binary_accuracy: 0.8348 - val_loss: 0.5614 - val_binary_accuracy: 0.7552
# Epoch 115/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3879 - binary_accuracy: 0.8383 - val_loss: 0.5712 - val_binary_accuracy: 0.7622
# Epoch 116/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3877 - binary_accuracy: 0.8330 - val_loss: 0.5611 - val_binary_accuracy: 0.7552
# Epoch 117/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3917 - binary_accuracy: 0.8278 - val_loss: 0.5602 - val_binary_accuracy: 0.7552
# Epoch 118/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3889 - binary_accuracy: 0.8330 - val_loss: 0.5601 - val_binary_accuracy: 0.7552
# Epoch 119/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3855 - binary_accuracy: 0.8348 - val_loss: 0.5704 - val_binary_accuracy: 0.7552
# Epoch 120/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3866 - binary_accuracy: 0.8278 - val_loss: 0.5609 - val_binary_accuracy: 0.7622
# Epoch 121/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3877 - binary_accuracy: 0.8295 - val_loss: 0.5685 - val_binary_accuracy: 0.7483
# Epoch 122/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3864 - binary_accuracy: 0.8330 - val_loss: 0.5708 - val_binary_accuracy: 0.7552
# Epoch 123/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3859 - binary_accuracy: 0.8348 - val_loss: 0.5748 - val_binary_accuracy: 0.7552
# Epoch 124/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3866 - binary_accuracy: 0.8383 - val_loss: 0.5636 - val_binary_accuracy: 0.7552
# Epoch 125/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3847 - binary_accuracy: 0.8348 - val_loss: 0.5682 - val_binary_accuracy: 0.7622
# Epoch 126/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3860 - binary_accuracy: 0.8383 - val_loss: 0.5686 - val_binary_accuracy: 0.7552
# Epoch 127/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3856 - binary_accuracy: 0.8366 - val_loss: 0.5721 - val_binary_accuracy: 0.7622
# Epoch 128/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3876 - binary_accuracy: 0.8348 - val_loss: 0.5719 - val_binary_accuracy: 0.7622
# Epoch 129/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3880 - binary_accuracy: 0.8348 - val_loss: 0.5721 - val_binary_accuracy: 0.7622
# Epoch 130/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3878 - binary_accuracy: 0.8383 - val_loss: 0.5849 - val_binary_accuracy: 0.7483
# Epoch 131/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3855 - binary_accuracy: 0.8348 - val_loss: 0.5774 - val_binary_accuracy: 0.7622
# Epoch 132/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3851 - binary_accuracy: 0.8330 - val_loss: 0.5708 - val_binary_accuracy: 0.7552
# Epoch 133/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3827 - binary_accuracy: 0.8383 - val_loss: 0.5748 - val_binary_accuracy: 0.7483
# Epoch 134/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3840 - binary_accuracy: 0.8348 - val_loss: 0.5717 - val_binary_accuracy: 0.7552
# Epoch 135/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3845 - binary_accuracy: 0.8348 - val_loss: 0.5777 - val_binary_accuracy: 0.7552
# Epoch 136/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3856 - binary_accuracy: 0.8366 - val_loss: 0.5774 - val_binary_accuracy: 0.7622
# Epoch 137/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3946 - binary_accuracy: 0.8278 - val_loss: 0.5764 - val_binary_accuracy: 0.7552
# Epoch 138/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3868 - binary_accuracy: 0.8383 - val_loss: 0.5755 - val_binary_accuracy: 0.7552
# Epoch 139/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3833 - binary_accuracy: 0.8366 - val_loss: 0.5782 - val_binary_accuracy: 0.7552
# Epoch 140/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3852 - binary_accuracy: 0.8383 - val_loss: 0.5803 - val_binary_accuracy: 0.7552
# Epoch 141/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3839 - binary_accuracy: 0.8348 - val_loss: 0.5891 - val_binary_accuracy: 0.7483
# Epoch 142/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3871 - binary_accuracy: 0.8330 - val_loss: 0.5783 - val_binary_accuracy: 0.7483
# Epoch 143/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3831 - binary_accuracy: 0.8383 - val_loss: 0.5860 - val_binary_accuracy: 0.7622
# Epoch 144/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3857 - binary_accuracy: 0.8348 - val_loss: 0.5742 - val_binary_accuracy: 0.7552
# Epoch 145/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3849 - binary_accuracy: 0.8330 - val_loss: 0.5845 - val_binary_accuracy: 0.7552
# Epoch 146/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3823 - binary_accuracy: 0.8383 - val_loss: 0.5838 - val_binary_accuracy: 0.7552
# Epoch 147/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3856 - binary_accuracy: 0.8330 - val_loss: 0.5840 - val_binary_accuracy: 0.7622
# Epoch 148/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.
300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3817 - binary_accuracy: 0.8348 - val_loss: 0.5946 - val_binary_accuracy: 0.7552
# Epoch 176/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3812 - binary_accuracy: 0.8383 - val_loss: 0.5935 - val_binary_accuracy: 0.7552
# Epoch 177/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3881 - binary_accuracy: 0.8295 - val_loss: 0.5981 - val_binary_accuracy: 0.7552
# Epoch 178/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3893 - binary_accuracy: 0.8313 - val_loss: 0.5924 - val_binary_accuracy: 0.7483
# Epoch 179/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3835 - binary_accuracy: 0.8383 - val_loss: 0.5966 - val_binary_accuracy: 0.7552
# Epoch 180/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3805 - binary_accuracy: 0.8383 - val_loss: 0.6005 - val_binary_accuracy: 0.7552
# Epoch 181/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3825 - binary_accuracy: 0.8366 - val_loss: 0.5980 - val_binary_accuracy: 0.7552
# Epoch 182/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3850 - binary_accuracy: 0.8330 - val_loss: 0.5997 - val_binary_accuracy: 0.7483
# Epoch 183/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3835 - binary_accuracy: 0.8348 - val_loss: 0.6003 - val_binary_accuracy: 0.7552
# Epoch 184/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3837 - binary_accuracy: 0.8348 - val_loss: 0.6000 - val_binary_accuracy: 0.7483
# Epoch 185/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3861 - binary_accuracy: 0.8330 - val_loss: 0.6069 - val_binary_accuracy: 0.7552
# Epoch 186/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3824 - binary_accuracy: 0.8383 - val_loss: 0.5963 - val_binary_accuracy: 0.7552
# Epoch 187/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3802 - binary_accuracy: 0.8348 - val_loss: 0.6034 - val_binary_accuracy: 0.7552
# Epoch 188/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3846 - binary_accuracy: 0.8366 - val_loss: 0.6134 - val_binary_accuracy: 0.7483
# Epoch 189/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3849 - binary_accuracy: 0.8366 - val_loss: 0.5974 - val_binary_accuracy: 0.7552
# Epoch 190/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3826 - binary_accuracy: 0.8366 - val_loss: 0.6005 - val_binary_accuracy: 0.7483
# Epoch 191/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3821 - binary_accuracy: 0.8366 - val_loss: 0.6063 - val_binary_accuracy: 0.7552
# Epoch 192/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3811 - binary_accuracy: 0.8366 - val_loss: 0.5994 - val_binary_accuracy: 0.7552
# Epoch 193/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3824 - binary_accuracy: 0.8348 - val_loss: 0.6037 - val_binary_accuracy: 0.7552
# Epoch 194/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3850 - binary_accuracy: 0.8330 - val_loss: 0.5997 - val_binary_accuracy: 0.7483
# Epoch 195/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3858 - binary_accuracy: 0.8366 - val_loss: 0.6020 - val_binary_accuracy: 0.7552
# Epoch 196/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3832 - binary_accuracy: 0.8366 - val_loss: 0.5996 - val_binary_accuracy: 0.7552
# Epoch 197/300
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3830 - binary_accuracy: 0.8348 - val_loss: 0.6142 - val_binary_accuracy: 0.7622
# Epoch 198/300
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3893 - binary_accuracy: 0.8295 - val_loss: 0.5924 - val_binary_accuracy: 0.7622
# Epoch 199/300
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3904 - binary_accuracy: 0.8366 - val_loss: 0.5987 - val_binary_accuracy: 0.7552
# Epoch 200/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3827 - binary_accuracy: 0.8348 - val_loss: 0.6133 - val_binary_accuracy: 0.7552
# Epoch 201/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3841 - binary_accuracy: 0.8366 - val_loss: 0.6066 - val_binary_accuracy: 0.7483
# Epoch 202/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3804 - binary_accuracy: 0.8383 - val_loss: 0.5997 - val_binary_accuracy: 0.7622
# Epoch 203/300
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3828 - binary_accuracy: 0.8383 - val_loss: 0.6019 - val_binary_accuracy: 0.7552
# Epoch 204/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3804 - binary_accuracy: 0.8366 - val_loss: 0.6057 - val_binary_accuracy: 0.7552
# Epoch 205/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3815 - binary_accuracy: 0.8313 - val_loss: 0.6092 - val_binary_accuracy: 0.7552
# Epoch 206/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3821 - binary_accuracy: 0.8383 - val_loss: 0.6106 - val_binary_accuracy: 0.7552
# Epoch 207/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3841 - binary_accuracy: 0.8366 - val_loss: 0.6107 - val_binary_accuracy: 0.7552
# Epoch 208/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3935 - binary_accuracy: 0.8207 - val_loss: 0.6098 - val_binary_accuracy: 0.7622
# Epoch 209/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3859 - binary_accuracy: 0.8330 - val_loss: 0.6172 - val_binary_accuracy: 0.7483
# Epoch 210/300
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3856 - binary_accuracy: 0.8383 - val_loss: 0.6031 - val_binary_accuracy: 0.7552
# Epoch 211/300
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3850 - binary_accuracy: 0.8348 - val_loss: 0.6089 - val_binary_accuracy: 0.7552
# Epoch 212/300
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3901 - binary_accuracy: 0.8295 - val_loss: 0.6048 - val_binary_accuracy: 0.7552
# Epoch 213/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3978 - binary_accuracy: 0.8278 - val_loss: 0.6073 - val_binary_accuracy: 0.7483
# Epoch 214/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3794 - binary_accuracy: 0.8366 - val_loss: 0.6000 - val_binary_accuracy: 0.7552
# Epoch 215/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3867 - binary_accuracy: 0.8383 - val_loss: 0.6128 - val_binary_accuracy: 0.7483
# Epoch 216/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3823 - binary_accuracy: 0.8348 - val_loss: 0.6002 - val_binary_accuracy: 0.7552
# Epoch 217/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3819 - binary_accuracy: 0.8366 - val_loss: 0.6221 - val_binary_accuracy: 0.7483
# Epoch 218/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3842 - binary_accuracy: 0.8313 - val_loss: 0.5999 - val_binary_accuracy: 0.7552
# Epoch 219/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3803 - binary_accuracy: 0.8366 - val_loss: 0.6169 - val_binary_accuracy: 0.7483
# Epoch 220/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3840 - binary_accuracy: 0.8348 - val_loss: 0.6130 - val_binary_accuracy: 0.7552
# Epoch 221/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3834 - binary_accuracy: 0.8366 - val_loss: 0.6079 - val_binary_accuracy: 0.7552
# Epoch 222/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3833 - binary_accuracy: 0.8330 - val_loss: 0.6136 - val_binary_accuracy: 0.7552
# Epoch 223/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3806 - binary_accuracy: 0.8366 - val_loss: 0.6112 - val_binary_accuracy: 0.7552
# Epoch 224/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3811 - binary_accuracy: 0.8348 - val_loss: 0.6076 - val_binary_accuracy: 0.7552
# Epoch 225/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3807 - binary_accuracy: 0.8366 - val_loss: 0.6194 - val_binary_accuracy: 0.7552
# Epoch 226/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3824 - binary_accuracy: 0.8330 - val_loss: 0.6084 - val_binary_accuracy: 0.7552
# Epoch 227/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3821 - binary_accuracy: 0.8366 - val_loss: 0.6137 - val_binary_accuracy: 0.7483
# Epoch 228/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3836 - binary_accuracy: 0.8366 - val_loss: 0.6047 - val_binary_accuracy: 0.7552
# Epoch 229/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3810 - binary_accuracy: 0.8330 - val_loss: 0.6243 - val_binary_accuracy: 0.7483
# Epoch 230/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3808 - binary_accuracy: 0.8348 - val_loss: 0.6086 - val_binary_accuracy: 0.7552
# Epoch 231/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3834 - binary_accuracy: 0.8366 - val_loss: 0.6149 - val_binary_accuracy: 0.7552
# Epoch 232/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3840 - binary_accuracy: 0.8348 - val_loss: 0.6089 - val_binary_accuracy: 0.7552
# Epoch 233/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3824 - binary_accuracy: 0.8330 - val_loss: 0.6154 - val_binary_accuracy: 0.7552
# Epoch 234/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3830 - binary_accuracy: 0.8330 - val_loss: 0.6117 - val_binary_accuracy: 0.7552
# Epoch 235/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3837 - binary_accuracy: 0.8348 - val_loss: 0.6178 - val_binary_accuracy: 0.7552
# Epoch 236/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3817 - binary_accuracy: 0.8366 - val_loss: 0.6166 - val_binary_accuracy: 0.7552
# Epoch 237/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3789 - binary_accuracy: 0.8401 - val_loss: 0.6194 - val_binary_accuracy: 0.7552
# Epoch 238/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3795 - binary_accuracy: 0.8383 - val_loss: 0.6169 - val_binary_accuracy: 0.7552
# Epoch 239/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3806 - binary_accuracy: 0.8330 - val_loss: 0.6257 - val_binary_accuracy: 0.7622
# Epoch 240/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3808 - binary_accuracy: 0.8348 - val_loss: 0.6181 - val_binary_accuracy: 0.7622
# Epoch 241/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3804 - binary_accuracy: 0.8330 - val_loss: 0.6155 - val_binary_accuracy: 0.7552
# Epoch 242/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3810 - binary_accuracy: 0.8348 - val_loss: 0.6297 - val_binary_accuracy: 0.7552
# Epoch 243/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3855 - binary_accuracy: 0.8330 - val_loss: 0.6148 - val_binary_accuracy: 0.7622
# Epoch 244/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3923 - binary_accuracy: 0.8243 - val_loss: 0.6131 - val_binary_accuracy: 0.7552
# Epoch 245/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3813 - binary_accuracy: 0.8313 - val_loss: 0.6168 - val_binary_accuracy: 0.7552
# Epoch 246/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3830 - binary_accuracy: 0.8330 - val_loss: 0.6164 - val_binary_accuracy: 0.7552
# Epoch 247/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3809 - binary_accuracy: 0.8348 - val_loss: 0.6130 - val_binary_accuracy: 0.7622
# Epoch 248/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3802 - binary_accuracy: 0.8366 - val_loss: 0.6174 - val_binary_accuracy: 0.7552
# Epoch 249/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3787 - binary_accuracy: 0.8348 - val_loss: 0.6258 - val_binary_accuracy: 0.7622
# Epoch 250/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3785 - binary_accuracy: 0.8366 - val_loss: 0.6164 - val_binary_accuracy: 0.7552
# Epoch 251/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3797 - binary_accuracy: 0.8313 - val_loss: 0.6209 - val_binary_accuracy: 0.7622
# Epoch 252/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3830 - binary_accuracy: 0.8330 - val_loss: 0.6264 - val_binary_accuracy: 0.7622
# Epoch 253/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3795 - binary_accuracy: 0.8330 - val_loss: 0.6194 - val_binary_accuracy: 0.7552
# Epoch 254/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3802 - binary_accuracy: 0.8383 - val_loss: 0.6252 - val_binary_accuracy: 0.7552
# Epoch 255/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3816 - binary_accuracy: 0.8348 - val_loss: 0.6260 - val_binary_accuracy: 0.7622
# Epoch 256/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3806 - binary_accuracy: 0.8366 - val_loss: 0.6251 - val_binary_accuracy: 0.7622
# Epoch 257/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3804 - binary_accuracy: 0.8366 - val_loss: 0.6272 - val_binary_accuracy: 0.7552
# Epoch 258/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3783 - binary_accuracy: 0.8348 - val_loss: 0.6324 - val_binary_accuracy: 0.7552
# Epoch 259/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3789 - binary_accuracy: 0.8383 - val_loss: 0.6239 - val_binary_accuracy: 0.7552
# Epoch 260/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3809 - binary_accuracy: 0.8366 - val_loss: 0.6412 - val_binary_accuracy: 0.7483
# Epoch 261/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3771 - binary_accuracy: 0.8348 - val_loss: 0.6242 - val_binary_accuracy: 0.7552
# Epoch 262/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3841 - binary_accuracy: 0.8348 - val_loss: 0.6225 - val_binary_accuracy: 0.7552
# Epoch 263/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3789 - binary_accuracy: 0.8366 - val_loss: 0.6261 - val_binary_accuracy: 0.7622
# Epoch 264/300
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3798 - binary_accuracy: 0.8383 - val_loss: 0.6273 - val_binary_accuracy: 0.7552
# Epoch 265/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3805 - binary_accuracy: 0.8330 - val_loss: 0.6335 - val_binary_accuracy: 0.7552
# Epoch 266/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3817 - binary_accuracy: 0.8348 - val_loss: 0.6275 - val_binary_accuracy: 0.7552
# Epoch 267/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3865 - binary_accuracy: 0.8313 - val_loss: 0.6251 - val_binary_accuracy: 0.7552
# Epoch 268/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3815 - binary_accuracy: 0.8401 - val_loss: 0.6257 - val_binary_accuracy: 0.7552
# Epoch 269/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3810 - binary_accuracy: 0.8348 - val_loss: 0.6320 - val_binary_accuracy: 0.7483
# Epoch 270/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3806 - binary_accuracy: 0.8313 - val_loss: 0.6249 - val_binary_accuracy: 0.7552
# Epoch 271/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3798 - binary_accuracy: 0.8330 - val_loss: 0.6295 - val_binary_accuracy: 0.7552
# Epoch 272/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3801 - binary_accuracy: 0.8401 - val_loss: 0.6272 - val_binary_accuracy: 0.7552
# Epoch 273/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3771 - binary_accuracy: 0.8383 - val_loss: 0.6310 - val_binary_accuracy: 0.7622
# Epoch 274/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3779 - binary_accuracy: 0.8366 - val_loss: 0.6376 - val_binary_accuracy: 0.7552
# Epoch 275/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3839 - binary_accuracy: 0.8295 - val_loss: 0.6271 - val_binary_accuracy: 0.7552
# Epoch 276/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3796 - binary_accuracy: 0.8348 - val_loss: 0.6388 - val_binary_accuracy: 0.7483
# Epoch 277/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3792 - binary_accuracy: 0.8366 - val_loss: 0.6341 - val_binary_accuracy: 0.7552
# Epoch 278/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3818 - binary_accuracy: 0.8366 - val_loss: 0.6353 - val_binary_accuracy: 0.7552
# Epoch 279/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3796 - binary_accuracy: 0.8330 - val_loss: 0.6384 - val_binary_accuracy: 0.7552
# Epoch 280/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3800 - binary_accuracy: 0.8348 - val_loss: 0.6343 - val_binary_accuracy: 0.7552
# Epoch 281/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3798 - binary_accuracy: 0.8348 - val_loss: 0.6304 - val_binary_accuracy: 0.7552
# Epoch 282/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3868 - binary_accuracy: 0.8260 - val_loss: 0.6257 - val_binary_accuracy: 0.7552
# Epoch 283/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3921 - binary_accuracy: 0.8295 - val_loss: 0.6322 - val_binary_accuracy: 0.7483
# Epoch 284/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3821 - binary_accuracy: 0.8348 - val_loss: 0.6273 - val_binary_accuracy: 0.7552
# Epoch 285/300
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3803 - binary_accuracy: 0.8330 - val_loss: 0.6316 - val_binary_accuracy: 0.7552
# Epoch 286/300
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3786 - binary_accuracy: 0.8418 - val_loss: 0.6355 - val_binary_accuracy: 0.7552
# Epoch 287/300
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3825 - binary_accuracy: 0.8366 - val_loss: 0.6324 - val_binary_accuracy: 0.7552
# Epoch 288/300
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3793 - binary_accuracy: 0.8313 - val_loss: 0.6267 - val_binary_accuracy: 0.7552
# Epoch 289/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3794 - binary_accuracy: 0.8348 - val_loss: 0.6400 - val_binary_accuracy: 0.7552
# Epoch 290/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3789 - binary_accuracy: 0.8348 - val_loss: 0.6319 - val_binary_accuracy: 0.7552
# Epoch 291/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3846 - binary_accuracy: 0.8278 - val_loss: 0.6391 - val_binary_accuracy: 0.7552
# Epoch 292/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3832 - binary_accuracy: 0.8225 - val_loss: 0.6313 - val_binary_accuracy: 0.7552
# Epoch 293/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3882 - binary_accuracy: 0.8366 - val_loss: 0.6423 - val_binary_accuracy: 0.7483
# Epoch 294/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3850 - binary_accuracy: 0.8453 - val_loss: 0.6344 - val_binary_accuracy: 0.7552
# Epoch 295/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3813 - binary_accuracy: 0.8366 - val_loss: 0.6306 - val_binary_accuracy: 0.7552
# Epoch 296/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3795 - binary_accuracy: 0.8348 - val_loss: 0.6531 - val_binary_accuracy: 0.7483
# Epoch 297/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3799 - binary_accuracy: 0.8366 - val_loss: 0.6317 - val_binary_accuracy: 0.7552
# Epoch 298/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.3766 - binary_accuracy: 0.8366 - val_loss: 0.6440 - val_binary_accuracy: 0.7552
# Epoch 299/300
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3787 - binary_accuracy: 0.8383 - val_loss: 0.6345 - val_binary_accuracy: 0.7552
# Epoch 300/300
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3795 - binary_accuracy: 0.8313 - val_loss: 0.6447 - val_binary_accuracy: 0.7552
# ein = 0.16871702671051025
# eout = 0.17318435754189943
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87       120
#            1       0.76      0.69      0.73        59
#
#     accuracy                           0.83       179
#    macro avg       0.81      0.79      0.80       179
# weighted avg       0.82      0.83      0.82       179

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss','Val Loss']);

# %%
plt.plot(epochs_hist.history['binary_accuracy'])
plt.plot(epochs_hist.history['val_binary_accuracy'])

plt.title('Model accuracy Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation accuracy')
plt.legend(['Training accuracy','Val accuracy']);

# %% [markdown]
# Fica claro o overfitting em uma rede tão grande contudo a rede original acaba por passar muitas épocas sem uma melhora no Eout
# com isso em mente utilizei a técnica de early stop

# %% [markdown]
# # Ajuste do modelo após avaliação

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=12, activation='relu', input_shape=(4, )))
model.add(tf.keras.layers.Dropout(0.05))
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 12)                60
#
#  dropout_1 (Dropout)         (None, 12)                0
#
#  dense_8 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer='Adam', loss='BinaryCrossentropy', metrics = ['binary_accuracy'])

# %%
es = EarlyStopping(monitor='val_binary_accuracy', mode='max', verbose=1, patience=50, restore_best_weights=True)

# %%
epochs_hist = model.fit(x_train, y_train, epochs = 300, validation_split = 0.2, callbacks = [es])
# Out:
# Epoch 1/300
# 18/18 [==============================] - 1s 8ms/step - loss: 0.7610 - binary_accuracy: 0.2812 - val_loss: 0.7365 - val_binary_accuracy: 0.3147
# Epoch 2/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7410 - binary_accuracy: 0.2777 - val_loss: 0.7228 - val_binary_accuracy: 0.3147
# Epoch 3/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7268 - binary_accuracy: 0.2531 - val_loss: 0.7116 - val_binary_accuracy: 0.2448
# Epoch 4/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7122 - binary_accuracy: 0.2285 - val_loss: 0.7035 - val_binary_accuracy: 0.2587
# Epoch 5/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7033 - binary_accuracy: 0.3374 - val_loss: 0.6971 - val_binary_accuracy: 0.5245
# Epoch 6/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6952 - binary_accuracy: 0.5448 - val_loss: 0.6921 - val_binary_accuracy: 0.5524
# Epoch 7/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6886 - binary_accuracy: 0.5923 - val_loss: 0.6876 - val_binary_accuracy: 0.6084
# Epoch 8/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6825 - binary_accuracy: 0.6028 - val_loss: 0.6828 - val_binary_accuracy: 0.6084
# Epoch 9/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6769 - binary_accuracy: 0.6274 - val_loss: 0.6779 - val_binary_accuracy: 0.6014
# Epoch 10/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6708 - binary_accuracy: 0.7012 - val_loss: 0.6725 - val_binary_accuracy: 0.6364
# Epoch 11/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6643 - binary_accuracy: 0.7241 - val_loss: 0.6662 - val_binary_accuracy: 0.6713
# Epoch 12/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6576 - binary_accuracy: 0.7399 - val_loss: 0.6593 - val_binary_accuracy: 0.7413
# Epoch 13/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6493 - binary_accuracy: 0.7803 - val_loss: 0.6528 - val_binary_accuracy: 0.7483
# Epoch 14/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6426 - binary_accuracy: 0.7680 - val_loss: 0.6458 - val_binary_accuracy: 0.7622
# Epoch 15/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6346 - binary_accuracy: 0.7680 - val_loss: 0.6393 - val_binary_accuracy: 0.7413
# Epoch 16/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6279 - binary_accuracy: 0.7733 - val_loss: 0.6337 - val_binary_accuracy: 0.7413
# Epoch 17/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6216 - binary_accuracy: 0.7750 - val_loss: 0.6272 - val_binary_accuracy: 0.7552
# Epoch 18/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6112 - binary_accuracy: 0.7856 - val_loss: 0.6209 - val_binary_accuracy: 0.7552
# Epoch 19/300
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6038 - binary_accuracy: 0.7786 - val_loss: 0.6143 - val_binary_accuracy: 0.7552
# Epoch 20/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5960 - binary_accuracy: 0.7786 - val_loss: 0.6085 - val_binary_accuracy: 0.7552
# Epoch 21/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5887 - binary_accuracy: 0.7680 - val_loss: 0.6023 - val_binary_accuracy: 0.7483
# Epoch 22/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5804 - binary_accuracy: 0.7768 - val_loss: 0.5967 - val_binary_accuracy: 0.7413
# Epoch 23/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5697 - binary_accuracy: 0.7909 - val_loss: 0.5910 - val_binary_accuracy: 0.7343
# Epoch 24/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5619 - binary_accuracy: 0.7891 - val_loss: 0.5855 - val_binary_accuracy: 0.7343
# Epoch 25/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5575 - binary_accuracy: 0.7873 - val_loss: 0.5805 - val_binary_accuracy: 0.7413
# Epoch 26/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5535 - binary_accuracy: 0.7786 - val_loss: 0.5755 - val_binary_accuracy: 0.7343
# Epoch 27/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5444 - binary_accuracy: 0.7873 - val_loss: 0.5704 - val_binary_accuracy: 0.7343
# Epoch 28/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5380 - binary_accuracy: 0.7926 - val_loss: 0.5659 - val_binary_accuracy: 0.7343
# Epoch 29/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5350 - binary_accuracy: 0.7873 - val_loss: 0.5613 - val_binary_accuracy: 0.7343
# Epoch 30/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5267 - binary_accuracy: 0.7873 - val_loss: 0.5576 - val_binary_accuracy: 0.7343
# Epoch 31/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5258 - binary_accuracy: 0.7750 - val_loss: 0.5543 - val_binary_accuracy: 0.7343
# Epoch 32/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5146 - binary_accuracy: 0.7873 - val_loss: 0.5509 - val_binary_accuracy: 0.7343
# Epoch 33/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5103 - binary_accuracy: 0.7873 - val_loss: 0.5478 - val_binary_accuracy: 0.7413
# Epoch 34/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5092 - binary_accuracy: 0.7838 - val_loss: 0.5452 - val_binary_accuracy: 0.7343
# Epoch 35/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5047 - binary_accuracy: 0.7838 - val_loss: 0.5420 - val_binary_accuracy: 0.7413
# Epoch 36/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4975 - binary_accuracy: 0.7838 - val_loss: 0.5395 - val_binary_accuracy: 0.7343
# Epoch 37/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4982 - binary_accuracy: 0.7821 - val_loss: 0.5370 - val_binary_accuracy: 0.7343
# Epoch 38/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4956 - binary_accuracy: 0.7803 - val_loss: 0.5346 - val_binary_accuracy: 0.7343
# Epoch 39/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4982 - binary_accuracy: 0.7786 - val_loss: 0.5324 - val_binary_accuracy: 0.7343
# Epoch 40/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4836 - binary_accuracy: 0.7803 - val_loss: 0.5306 - val_binary_accuracy: 0.7343
# Epoch 41/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4836 - binary_accuracy: 0.7873 - val_loss: 0.5291 - val_binary_accuracy: 0.7413
# Epoch 42/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4836 - binary_accuracy: 0.7891 - val_loss: 0.5277 - val_binary_accuracy: 0.7413
# Epoch 43/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4788 - binary_accuracy: 0.7909 - val_loss: 0.5264 - val_binary_accuracy: 0.7413
# Epoch 44/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4736 - binary_accuracy: 0.7803 - val_loss: 0.5248 - val_binary_accuracy: 0.7413
# Epoch 45/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4772 - binary_accuracy: 0.7821 - val_loss: 0.5238 - val_binary_accuracy: 0.7343
# Epoch 46/300
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4731 - binary_accuracy: 0.7803 - val_loss: 0.5231 - val_binary_accuracy: 0.7483
# Epoch 47/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4755 - binary_accuracy: 0.7856 - val_loss: 0.5221 - val_binary_accuracy: 0.7413
# Epoch 48/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4747 - binary_accuracy: 0.7768 - val_loss: 0.5214 - val_binary_accuracy: 0.7413
# Epoch 49/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4640 - binary_accuracy: 0.7996 - val_loss: 0.5201 - val_binary_accuracy: 0.7413
# Epoch 50/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4678 - binary_accuracy: 0.7944 - val_loss: 0.5196 - val_binary_accuracy: 0.7413
# Epoch 51/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4703 - binary_accuracy: 0.7873 - val_loss: 0.5185 - val_binary_accuracy: 0.7413
# Epoch 52/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4650 - binary_accuracy: 0.7821 - val_loss: 0.5179 - val_binary_accuracy: 0.7413
# Epoch 53/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4612 - binary_accuracy: 0.7873 - val_loss: 0.5169 - val_binary_accuracy: 0.7413
# Epoch 54/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4645 - binary_accuracy: 0.7856 - val_loss: 0.5162 - val_binary_accuracy: 0.7413
# Epoch 55/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4650 - binary_accuracy: 0.7838 - val_loss: 0.5157 - val_binary_accuracy: 0.7413
# Epoch 56/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4605 - binary_accuracy: 0.7838 - val_loss: 0.5146 - val_binary_accuracy: 0.7413
# Epoch 57/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4616 - binary_accuracy: 0.7909 - val_loss: 0.5136 - val_binary_accuracy: 0.7413
# Epoch 58/300
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4563 - binary_accuracy: 0.7873 - val_loss: 0.5129 - val_binary_accuracy: 0.7413
# Epoch 59/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4528 - binary_accuracy: 0.7873 - val_loss: 0.5122 - val_binary_accuracy: 0.7413
# Epoch 60/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4684 - binary_accuracy: 0.7838 - val_loss: 0.5121 - val_binary_accuracy: 0.7413
# Epoch 61/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4597 - binary_accuracy: 0.7961 - val_loss: 0.5114 - val_binary_accuracy: 0.7413
# Epoch 62/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4590 - binary_accuracy: 0.7961 - val_loss: 0.5113 - val_binary_accuracy: 0.7413
# Epoch 63/300
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4547 - binary_accuracy: 0.7961 - val_loss: 0.5100 - val_binary_accuracy: 0.7413
# Epoch 64/300
#  1/18 [>.............................] - ETA: 0s - loss: 0.3905 - binary_accuracy: 0.8125Restoring model weights from the end of the best epoch: 14.
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4508 - binary_accuracy: 0.7961 - val_loss: 0.5095 - val_binary_accuracy: 0.7413
# Epoch 64: early stopping

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
print("ein =", 1-epochs_hist.history['val_binary_accuracy'][-1])
print("eout =", 1 - accuracy_score(y_test,y_pred))
# Out:
# ein = 0.25874125957489014
# eout = 0.16759776536312854

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss','Val Loss']);

# %%
plt.plot(epochs_hist.history['binary_accuracy'])
plt.plot(epochs_hist.history['val_binary_accuracy'])

plt.title('Model accuracy Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation accuracy')
plt.legend(['Training accuracy','Val accuracy']);

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.89       120
#            1       0.91      0.54      0.68        59
#
#     accuracy                           0.83       179
#    macro avg       0.86      0.76      0.78       179
# weighted avg       0.85      0.83      0.82       179

# %% [markdown]
# ### Test contra solver base sklearn

# %% [markdown]
# Esse test foi realizado a título de curiosidade, afim de ver como se sai uma rede tão pequena contra um solver com diversas otmizações

# %% [markdown]
# O solver base do *sklearn* usa:
# * Camada única de 100 neúronios
# * 200 épocas
# * Função de ativação ReLu
# * solver Adam

# %%
#camada única de 100 neuronios é a construção base dele
model = MLPClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87       120
#            1       0.76      0.69      0.73        59
#
#     accuracy                           0.83       179
#    macro avg       0.81      0.79      0.80       179
# weighted avg       0.82      0.83      0.82       179
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# # Construção do modelo de Árvore de Decisão

# %%
#criando uma validação para os plots futuros
x_train_tree, x_val_tree, y_train_tree, y_val_tree = train_test_split(X_scaled,y, test_size=0.2)

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)

print('Ein: %0.4f' % (1 - accuracy_score(y_train_tree, clf.predict(x_train_tree))))
print('Eout: %0.4f' % (1 - accuracy_score(y_test, clf.predict(x_test))))
print(classification_report(y_test, clf.predict(x_test)))
# Out:
# Ein: 0.1081
# Eout: 0.1620
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       120
#            1       0.77      0.73      0.75        59
#
#     accuracy                           0.84       179
#    macro avg       0.82      0.81      0.81       179
# weighted avg       0.84      0.84      0.84       179

# %% [markdown]
# Lista dos atributos dos dados com o seu valor de importância usado na divisão dos nós da árvore de decisão.

# %%
for feature, importance in zip(x.columns, clf.feature_importances_):
    print("{}:{}".format(feature, importance))

plt.bar(x.columns, clf.feature_importances_);
# Out:
# Pclass:0.17591404284975717
# Sex:0.38593283365970643
# Age:0.36754605419270714
# Parch:0.07060706929782926

# %% [markdown]
# ### Plote a árvore de decisão criada pelo classificador usando a função plot_tree

# %%
# feature labels
features_label = x.columns

# class label
class_label = ['0','1']

plt.figure(figsize=(50,20))
plot_tree(
    clf, 
    feature_names = features_label,
    class_names = class_label, 
    filled=True, 
    proportion = True,
    fontsize=6, 
    rounded = True)

plt.savefig('arvore_original.png')
plt.show()

# %%
#Recupera os valores efetivos de alpha para a elaboração da fase de prunning
path = clf.cost_complexity_pruning_path(x_train_tree, y_train_tree)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

#Plota a relação entre os valores de alpha e impureza das folhas
fig, ax = plt.subplots()
ax.plot(ccp_alphas[:-1], impurities[:-1], marker="o", drawstyle="steps-post")
ax.set_xlabel("alpha efetivo")
ax.set_ylabel("total impureza das folhas")
ax.set_title("Alpha Vs impureza no conjunto de treino")

print(len(ccp_alphas))
print(impurities)
# Out:
# 66
# [0.12876418 0.12876418 0.12876418 0.12876418 0.12877198 0.12881657
#  0.12887899 0.12901554 0.12910918 0.12934326 0.12958003 0.13036617
#  0.13120887 0.13242059 0.1327483  0.13348399 0.13498763 0.13536478
#  0.13583294 0.13676927 0.13727642 0.13832979 0.13958645 0.14239543
#  0.14590667 0.14667714 0.14903862 0.14988132 0.15072402 0.15431328
#  0.15795828 0.16072112 0.16349215 0.16536481 0.16630114 0.16914317
#  0.17009901 0.17220575 0.17431249 0.17958827 0.18304801 0.18550922
#  0.1880061  0.18951092 0.19431309 0.1976243  0.20121061 0.20308327
#  0.20497154 0.21088212 0.21290624 0.21501298 0.21936436 0.22615925
#  0.22856696 0.23345395 0.23603629 0.24471224 0.25424343 0.25814481
#  0.26227055 0.2681549  0.28276661 0.29764275 0.3324778  0.47411548]

# %%
clfs = []
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(x_train_tree, y_train_tree)
    clfs.append(clf)

#Descarta o último por ser trivial (apenas o nó raiz)
clfs = clfs[:-1]
ccp_alphas = ccp_alphas[:-1]

node_counts = [clf.tree_.node_count for clf in clfs]
depth = [clf.tree_.max_depth for clf in clfs]
fig, ax = plt.subplots(2, 1)
ax[0].plot(ccp_alphas, node_counts, marker="o", drawstyle="steps-post")
ax[0].set_xlabel("alpha")
ax[0].set_ylabel("número de nós")
ax[0].set_title("Número de nós vs alpha")
ax[1].plot(ccp_alphas, depth, marker="o", drawstyle="steps-post")
ax[1].set_xlabel("alpha")
ax[1].set_ylabel("profundidade da árvore")
ax[1].set_title("Profundidade vs alpha")
fig.tight_layout()

# %%
train_scores = [clf.score(x_train_tree, y_train_tree) for clf in clfs]
val_scores = [clf.score(x_val_tree, y_val_tree) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker="o", label="train", drawstyle="steps-post")
ax.plot(ccp_alphas, val_scores, marker="o", label="validation", drawstyle="steps-post")
ax.legend()
plt.show()

best_acc = 0
for v, i in zip(val_scores, range(len(val_scores))):
    if best_acc < v:
        best_acc = v
        best_alpha = clfs[i].ccp_alpha

print(best_alpha)
# Out:
# 0.0006283264340626855

# %% [markdown]
# ### Modificando o algoritmo de acordo com melhor alpha no conjunto de validação

# %%
clf = DecisionTreeClassifier(random_state=0, ccp_alpha=best_alpha)
clf.fit(x_train_tree, y_train_tree)

print('Ein: %0.4f' % (1 - accuracy_score(y_train_tree, clf.predict(x_train_tree))))
print('Eout: %0.4f' % (1 - accuracy_score(y_test, clf.predict(x_test))))
print(classification_report(y_test, clf.predict(x_test)))
# Out:
# Ein: 0.0969
# Eout: 0.1061
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92       120
#            1       0.88      0.78      0.83        59
#
#     accuracy                           0.89       179
#    macro avg       0.89      0.86      0.88       179
# weighted avg       0.89      0.89      0.89       179

# %%
# feature labels
features_label = x.columns

# class label
class_label = ['0','1']

plt.figure(figsize=(50,20))
plot_tree(
    clf, 
    feature_names = features_label,
    class_names = class_label, 
    filled=True, 
    proportion = True,
    fontsize=6, 
    rounded = True)

plt.savefig('arvore_podada.png')
plt.show()

# %% [markdown]
# # svm

# %%
#número de vetores de suporte
model = SVC(kernel='linear')
model.fit(x_train, y_train)

print("#VS: " + str(model.n_support_))
print(model.support_vectors_)
# Out:
# #VS: [164 164]
# [[1.         0.         0.0375     0.16666667]
#  [1.         0.         0.1        0.16666667]
#  [0.         1.         0.7625     0.        ]
#  ...
#  [0.         1.         0.3375     0.        ]
#  [1.         1.         0.35       0.16666667]
#  [0.5        0.         0.5        0.16666667]]

# %%
svm_ = svm.SVC(kernel='rbf')

# Create the random grid
param_grid = {
              'C' : np.linspace(1,10,20),
              'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5] 
              }

CV_rf = GridSearchCV(estimator=svm_, param_grid=param_grid, cv = 5, verbose=2, n_jobs=-1)


# Fit the random search model
CV_rf.fit(x_train, y_train)

print(CV_rf.best_estimator_)
# print(CV_rf.best_params_)


print('Ein: %0.4f' % (1 - accuracy_score(y_train, CV_rf.predict(x_train))))
print('Eout: %0.4f' % (1 - accuracy_score(y_test, CV_rf.predict(x_test))))
print(classification_report(y_test, CV_rf.predict(x_test)))
# Out:
# Fitting 5 folds for each of 160 candidates, totalling 800 fits
# SVC(gamma=0.5)
# Ein: 0.2163
# Eout: 0.1676
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88       120
#            1       0.75      0.73      0.74        59
#
#     accuracy                           0.83       179
#    macro avg       0.81      0.81      0.81       179
# weighted avg       0.83      0.83      0.83       179

# %% [markdown]
# # Conclusão

# %% [markdown]
# Fica claro que o melhor desempenho foi atingido utilizando árvore, oque provalvelmente se deve ao fato dos dados não estarem totalmente balanceados pois temos 429 amostras da classe "0" e 283 da classe "1" no conjunto de treino, sendo assim talvez o próximo passo nessa analise seria balancear os dados e testar denovo contudo não faz parte do objetivo da disciplina

# %%
y_train.value_counts()
# Out:
# 0    429
# 1    283
# Name: Survived, dtype: int64

# %%
y_train.value_counts(normalize = True)
# Out:
# 0    0.602528
# 1    0.397472
# Name: Survived, dtype: float64
