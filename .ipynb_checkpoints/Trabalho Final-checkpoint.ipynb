# %% [markdown]
# # Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

import sklearn
import random

from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier

from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

#utils
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier,MLPRegressor
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Importação dos dados

# %%
def read_instance(filepath):
    data = pd.read_csv(filepath)
    return(data)

# %%
data = read_instance('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# # Exploração inicial dos dados

# %%
mulher = data.loc[data.Sex == 'female']["Survived"]
m_sobrevivente = sum(mulher)/len(mulher)

print("% de mulheres sobreviventes:", m_sobrevivente )

homem = data.loc[data.Sex == 'male']["Survived"]
h_sobrevivente = sum(homem)/len(homem)

print("% de mulheres sobreviventes:", h_sobrevivente )

sns.barplot(x="Sex", y="Survived", data=data);
# Out:
# % de mulheres sobreviventes: 0.7420382165605095
# % de mulheres sobreviventes: 0.18890814558058924

# %%
sns.barplot(x="Pclass", y="Survived", data=data);

# %%
sns.barplot(x="Embarked", y="Survived", data=data);

# %%
sns.barplot(x="SibSp", y="Survived", data=data);

# %%
sns.barplot(x="Parch", y="Survived", data=data);

# %%
data["Age"] = data["Age"].fillna(0)
bins = [-1, 0, 12, 18, 25, 45, np.inf]
labels = ['-1', 'bebe', 'criança', 'adolecente', 'adulto', 'velho']
data['Grupo idade'] = pd.cut(data["Age"], bins, labels = labels)

sns.barplot(x="Grupo idade", y="Survived", data=data)
plt.show()

# %% [markdown]
# # Limpeza dos dados

# %%
def clean_data(data):
    #data = read_instance(data)
    #retirando a coluna de nomes, local de embarque, tarifa do passageiro, 
    #numero do ticket 
    data = data.drop(columns=['Name'])
    data = data.drop(columns=['Ticket'])
    data = data.drop(columns=['SibSp'])
    data = data.drop(columns=['Embarked'])
    data = data.drop(columns=['Cabin'])
    data = data.drop(columns=['PassengerId'])
    data = data.drop(columns=['Fare'])
    
    media_age = data.Age.median()
    data.fillna(media_age, inplace = True)
    
    data["Age"] = data["Age"].astype(int)
    
    # escolher se tirar cabine ou não pois a cabine infere no setor do barco
    data = data.dropna()
    #trocando valores de male e female por 1 e 0
    data.loc[data.Sex=='male','Sex'] = 1
    data.loc[data.Sex=='female','Sex'] = 0
    return data

# %%
data = read_instance('train.csv')

# %%
sns.heatmap(data.corr(), annot = True);

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data = clean_data(data)
data
# Out:
#      Survived  Pclass Sex  Age  Parch
# 0           0       3   1   22      0
# 1           1       1   0   38      0
# 2           1       3   0   26      0
# 3           1       1   0   35      0
# 4           0       3   1   35      0
# ..        ...     ...  ..  ...    ...
# 886         0       2   1   27      0
# 887         1       1   0   19      0
# 888         0       3   0   28      2
# 889         1       1   1   26      0
# 890         0       3   1   32      0
#
# [891 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    int32
#  4   Parch     891 non-null    int64
# dtypes: int32(1), int64(3), object(1)
# memory usage: 38.3+ KB

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       Parch
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.345679    0.381594
# std      0.486592    0.836071   13.028212    0.806057
# min      0.000000    1.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000
# 50%      0.000000    3.000000   28.000000    0.000000
# 75%      1.000000    3.000000   35.000000    0.000000
# max      1.000000    3.000000   80.000000    6.000000

# %%
data.shape
# Out:
# (891, 5)

# %% [markdown]
# # Criação e normalização treino e teste

# %%
x,y = data.drop(columns=['Survived']), data['Survived']

# %%
x
# Out:
#      Pclass Sex  Age  Parch
# 0         3   1   22      0
# 1         1   0   38      0
# 2         3   0   26      0
# 3         1   0   35      0
# 4         3   1   35      0
# ..      ...  ..  ...    ...
# 886       2   1   27      0
# 887       1   0   19      0
# 888       3   0   28      2
# 889       1   1   26      0
# 890       3   1   32      0
#
# [891 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# Normalização por causa dos grandes valores da coluna idade, não é necessário normalizar y pois ele já está entre 0 e 1

# %%
scaler = MinMaxScaler() # padrão (0,1)
X_scaled = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(X_scaled,y, test_size=0.2)

# %%
print("Shape X_train: ",x_train.shape)
print("Shape y_train: ",y_train.shape)
# Out:
# Shape X_train:  (712, 4)
# Shape y_train:  (712,)

# %%
print("Shape X_test: ",x_test.shape)
print("Shape y_test: ",y_test.shape)
# Out:
# Shape X_test:  (179, 4)
# Shape y_test:  (179,)

# %%
x_train
# Out:
# array([[1.        , 1.        , 0.125     , 0.33333333],
#        [1.        , 1.        , 0.5       , 0.66666667],
#        [1.        , 1.        , 0.4125    , 0.        ],
#        ...,
#        [1.        , 1.        , 0.35      , 0.        ],
#        [1.        , 0.        , 0.35      , 0.        ],
#        [1.        , 1.        , 0.2625    , 0.        ]])

# %% [markdown]
# #  Implementação do modelo baseado em Rede Neural

# %%
#foram esscolhidos 12 neuronios em camada unica por causa do numero de exemplos passados o objetivo era ter 71 parametros

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=6, activation='relu', input_shape=(4, )))
model.add(tf.keras.layers.Dense(units=6, activation='relu'))
model.add(tf.keras.layers.Dropout(0.02))
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 6)                 30
#
#  dense_10 (Dense)            (None, 6)                 42
#
#  dropout_3 (Dropout)         (None, 6)                 0
#
#  dense_11 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 79
# Trainable params: 79
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='categorical_hinge', metrics = ['accuracy'])

# %%
epochs_hist = model.fit(x_train, y_train, epochs = 100, validation_split = 0.2)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 9ms/step - loss: 1.1450 - accuracy: 0.3339 - val_loss: 1.1490 - val_accuracy: 0.3077
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.1360 - accuracy: 0.3234 - val_loss: 1.1419 - val_accuracy: 0.4266
# Epoch 3/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.1903 - accuracy: 0.4375

# %%
y_pred = model.predict(x_test)

# %%
y_pred[:5]
# Out:
# array([[9.8452705e-01],
#        [2.7793348e-03],
#        [6.4522028e-04],
#        [2.3636222e-03],
#        [8.6091837e-05]], dtype=float32)

# %%
#sigmoid retorna probabilidade
y_pred = (y_pred > 0.5)

# %% [markdown]
# # Avaliação do modelo

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
print("ein =", 1-epochs_hist.history['accuracy'][-1])
print("eout =", 1-accuracy_score(y_test,y_pred))
# Out:
# ein = 0.19156414270401
# eout = 0.2067039106145251

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss','Val Loss']);

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.94      0.84       101
#            1       0.89      0.60      0.72        78
#
#     accuracy                           0.79       179
#    macro avg       0.82      0.77      0.78       179
# weighted avg       0.81      0.79      0.78       179

# %% [markdown]
# # Ajuste do modelo após avaliação

# %% [markdown]
# Com base no gráfico acima por volta da epoca 40 o aprendizado fica muito baixo por época sendo assim farei com 50 épocas

# %% [markdown]
# ### Testando contra o solver base do sklearn

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=12, activation='relu', input_shape=(4, )))
model.add(tf.keras.layers.Dropout(0.02))
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
model.compile(optimizer='Adam', loss='categorical_hinge', metrics = ['accuracy'])

# %%
epochs_hist = model.fit(x_train, y_train, epochs = 50, validation_split = 0.2)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 8ms/step - loss: 1.1813 - accuracy: 0.3726 - val_loss: 1.1760 - val_accuracy: 0.3706
# Epoch 2/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.1701 - accuracy: 0.3726 - val_loss: 1.1660 - val_accuracy: 0.3706
# Epoch 3/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.1612 - accuracy: 0.3726 - val_loss: 1.1554 - val_accuracy: 0.3706
# Epoch 4/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.1504 - accuracy: 0.3708 - val_loss: 1.1458 - val_accuracy: 0.3706
# Epoch 5/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.1408 - accuracy: 0.3708 - val_loss: 1.1365 - val_accuracy: 0.3706
# Epoch 6/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.1311 - accuracy: 0.3884 - val_loss: 1.1270 - val_accuracy: 0.3706
# Epoch 7/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.1216 - accuracy: 0.5852 - val_loss: 1.1175 - val_accuracy: 0.7133
# Epoch 8/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.1120 - accuracy: 0.7469 - val_loss: 1.1090 - val_accuracy: 0.7832
# Epoch 9/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.1046 - accuracy: 0.7733 - val_loss: 1.1012 - val_accuracy: 0.7832
# Epoch 10/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0965 - accuracy: 0.7768 - val_loss: 1.0932 - val_accuracy: 0.7972
# Epoch 11/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0889 - accuracy: 0.7803 - val_loss: 1.0852 - val_accuracy: 0.7972
# Epoch 12/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0793 - accuracy: 0.7891 - val_loss: 1.0772 - val_accuracy: 0.8042
# Epoch 13/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0727 - accuracy: 0.7750 - val_loss: 1.0691 - val_accuracy: 0.8042
# Epoch 14/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0650 - accuracy: 0.7768 - val_loss: 1.0612 - val_accuracy: 0.8042
# Epoch 15/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0568 - accuracy: 0.7786 - val_loss: 1.0534 - val_accuracy: 0.8042
# Epoch 16/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0477 - accuracy: 0.7821 - val_loss: 1.0456 - val_accuracy: 0.8042
# Epoch 17/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0416 - accuracy: 0.7838 - val_loss: 1.0380 - val_accuracy: 0.8042
# Epoch 18/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0331 - accuracy: 0.7786 - val_loss: 1.0302 - val_accuracy: 0.8042
# Epoch 19/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0241 - accuracy: 0.7891 - val_loss: 1.0225 - val_accuracy: 0.8042
# Epoch 20/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0189 - accuracy: 0.7803 - val_loss: 1.0152 - val_accuracy: 0.8042
# Epoch 21/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0130 - accuracy: 0.7838 - val_loss: 1.0081 - val_accuracy: 0.8042
# Epoch 22/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0044 - accuracy: 0.7821 - val_loss: 1.0009 - val_accuracy: 0.8042
# Epoch 23/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9989 - accuracy: 0.7838 - val_loss: 0.9938 - val_accuracy: 0.8042
# Epoch 24/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9955 - accuracy: 0.7750 - val_loss: 0.9871 - val_accuracy: 0.8042
# Epoch 25/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9865 - accuracy: 0.7803 - val_loss: 0.9807 - val_accuracy: 0.8042
# Epoch 26/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9755 - accuracy: 0.7873 - val_loss: 0.9741 - val_accuracy: 0.8042
# Epoch 27/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9723 - accuracy: 0.7821 - val_loss: 0.9678 - val_accuracy: 0.8042
# Epoch 28/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9691 - accuracy: 0.7786 - val_loss: 0.9618 - val_accuracy: 0.8042
# Epoch 29/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9605 - accuracy: 0.7891 - val_loss: 0.9558 - val_accuracy: 0.8042
# Epoch 30/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9578 - accuracy: 0.7768 - val_loss: 0.9501 - val_accuracy: 0.8042
# Epoch 31/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9522 - accuracy: 0.7838 - val_loss: 0.9446 - val_accuracy: 0.8042
# Epoch 32/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9466 - accuracy: 0.7838 - val_loss: 0.9392 - val_accuracy: 0.8042
# Epoch 33/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9426 - accuracy: 0.7856 - val_loss: 0.9342 - val_accuracy: 0.8042
# Epoch 34/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9363 - accuracy: 0.7873 - val_loss: 0.9292 - val_accuracy: 0.8042
# Epoch 35/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9328 - accuracy: 0.7856 - val_loss: 0.9244 - val_accuracy: 0.8042
# Epoch 36/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9279 - accuracy: 0.7821 - val_loss: 0.9199 - val_accuracy: 0.8042
# Epoch 37/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9287 - accuracy: 0.7786 - val_loss: 0.9155 - val_accuracy: 0.8042
# Epoch 38/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9182 - accuracy: 0.7856 - val_loss: 0.9114 - val_accuracy: 0.8042
# Epoch 39/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9186 - accuracy: 0.7838 - val_loss: 0.9073 - val_accuracy: 0.8042
# Epoch 40/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9131 - accuracy: 0.7909 - val_loss: 0.9036 - val_accuracy: 0.8042
# Epoch 41/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9128 - accuracy: 0.7821 - val_loss: 0.9001 - val_accuracy: 0.8042
# Epoch 42/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9064 - accuracy: 0.7856 - val_loss: 0.8968 - val_accuracy: 0.8042
# Epoch 43/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9035 - accuracy: 0.7838 - val_loss: 0.8936 - val_accuracy: 0.8042
# Epoch 44/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8994 - accuracy: 0.7873 - val_loss: 0.8906 - val_accuracy: 0.8042
# Epoch 45/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9008 - accuracy: 0.7821 - val_loss: 0.8877 - val_accuracy: 0.8042
# Epoch 46/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8965 - accuracy: 0.7821 - val_loss: 0.8851 - val_accuracy: 0.8042
# Epoch 47/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8933 - accuracy: 0.7909 - val_loss: 0.8824 - val_accuracy: 0.8042
# Epoch 48/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.8927 - accuracy: 0.7873 - val_loss: 0.8800 - val_accuracy: 0.8042
# Epoch 49/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.8923 - accuracy: 0.7838 - val_loss: 0.8777 - val_accuracy: 0.8042
# Epoch 50/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.8864 - accuracy: 0.7838 - val_loss: 0.8754 - val_accuracy: 0.8042

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
print("ein =", 1-epochs_hist.history['accuracy'][-1])
print("eout =", 1 - accuracy_score(y_test,y_pred))
# Out:
# ein = 0.21616870164871216
# eout = 0.22346368715083798

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss','Val Loss']);

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81       102
#            1       0.77      0.69      0.73        77
#
#     accuracy                           0.78       179
#    macro avg       0.77      0.77      0.77       179
# weighted avg       0.78      0.78      0.77       179

# %% [markdown]
# # test contra solver base sklearn

# %%
#camada única de 100 neuronios é a construção base dele
model = MLPClassifier(activation='tanh', max_iter=50,solver ='adam')
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81       102
#            1       0.77      0.69      0.73        77
#
#     accuracy                           0.78       179
#    macro avg       0.77      0.77      0.77       179
# weighted avg       0.78      0.78      0.77       179
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# # Construção do modelo de Árvore de Decisão

# %%
#criando uma validação para os plots futuros
x_train_tree, x_val_tree, y_train_tree, y_val_tree = train_test_split(X_scaled,y, test_size=0.2)

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)

print('Ein: %0.4f' % (1 - accuracy_score(y_train_tree, clf.predict(x_train_tree))))
print('Eout: %0.4f' % (1 - accuracy_score(y_test, clf.predict(x_test))))
print(classification_report(y_test, clf.predict(x_test)))
# Out:
# Ein: 0.1067
# Eout: 0.1844
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85       102
#            1       0.89      0.65      0.75        77
#
#     accuracy                           0.82       179
#    macro avg       0.84      0.80      0.80       179
# weighted avg       0.83      0.82      0.81       179

# %% [markdown]
# Lista dos atributos dos dados com o seu valor de importância usado na divisão dos nós da árvore de decisão.

# %%
#código do professor 
for feature, importance in zip(x.columns, clf.feature_importances_):
    print("{}:{}".format(feature, importance))

plt.bar(x.columns, clf.feature_importances_)
# Out:
# Pclass:0.1763837775957353
# Sex:0.4138002544790595
# Age:0.3473753881731115
# Parch:0.06244057975209365
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Plote a árvore de decisão criada pelo classificador usando a função plot_tree

# %%
#codigo do professor 
# feature labels
features_label = x.columns

# class label
class_label = ['0','1']

plt.figure(figsize=(50,20))
plot_tree(
    clf, 
    feature_names = features_label,
    class_names = class_label, 
    filled=True, 
    proportion = True,
    fontsize=6, 
    rounded = True)

plt.savefig('arvore_original.png')
plt.show()

# %%
#Recupera os valores efetivos de alpha para a elaboração da fase de prunning
path = clf.cost_complexity_pruning_path(x_train_tree, y_train_tree)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

#Plota a relação entre os valores de alpha e impureza das folhas
fig, ax = plt.subplots()
ax.plot(ccp_alphas[:-1], impurities[:-1], marker="o", drawstyle="steps-post")
ax.set_xlabel("alpha efetivo")
ax.set_ylabel("total impureza das folhas")
ax.set_title("Impureza vs alpha efetivo para os dados de treino")

print(len(ccp_alphas))
print(impurities)
# Out:
# 71
# [0.12000689 0.12000689 0.12000689 0.12000689 0.12000782 0.12001115
#  0.12001629 0.1200248  0.12005601 0.12016951 0.12023124 0.12030927
#  0.12052485 0.12079488 0.12093533 0.12107578 0.12121623 0.12137229
#  0.12186688 0.12210097 0.12233505 0.12283152 0.12309904 0.12337994
#  0.12425095 0.12454505 0.12484234 0.12580375 0.12615488 0.12652941
#  0.12737211 0.12784027 0.12830844 0.12940082 0.13051445 0.13109966
#  0.13233041 0.13584165 0.13873576 0.13957846 0.14210655 0.14470791
#  0.14832628 0.15019894 0.15113527 0.15709695 0.15913347 0.16325778
#  0.16446163 0.16566548 0.16818187 0.1707279  0.17372415 0.18289238
#  0.18752258 0.19236269 0.20324337 0.20526749 0.20948097 0.22259506
#  0.22484225 0.22938075 0.24308473 0.24557746 0.24949347 0.2547095
#  0.25995294 0.27142524 0.28352275 0.31980298 0.46587789]

# %%
clfs = []
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(x_train_tree, y_train_tree)
    clfs.append(clf)

#Descarta o último por ser trivial (apenas o nó raiz)
clfs = clfs[:-1]
ccp_alphas = ccp_alphas[:-1]

node_counts = [clf.tree_.node_count for clf in clfs]
depth = [clf.tree_.max_depth for clf in clfs]
fig, ax = plt.subplots(2, 1)
ax[0].plot(ccp_alphas, node_counts, marker="o", drawstyle="steps-post")
ax[0].set_xlabel("alpha")
ax[0].set_ylabel("número de nós")
ax[0].set_title("Número de nós vs alpha")
ax[1].plot(ccp_alphas, depth, marker="o", drawstyle="steps-post")
ax[1].set_xlabel("alpha")
ax[1].set_ylabel("profundidade da árvore")
ax[1].set_title("Profundidade vs alpha")
fig.tight_layout()

# %%
train_scores = [clf.score(x_train_tree, y_train_tree) for clf in clfs]
val_scores = [clf.score(x_val_tree, y_val_tree) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker="o", label="train", drawstyle="steps-post")
ax.plot(ccp_alphas, val_scores, marker="o", label="validation", drawstyle="steps-post")
ax.legend()
plt.show()

best_acc = 0
for v, i in zip(val_scores, range(len(val_scores))):
    if best_acc < v:
        best_acc = v
        best_alpha = clfs[i].ccp_alpha

print(best_alpha)
# Out:
# 0.002106741573033708

# %% [markdown]
# ### Modificando o algoritmo de acordo com melhor alpha no conjunto de validação

# %%
clf = DecisionTreeClassifier(random_state=0, ccp_alpha=best_alpha)
clf.fit(x_train_tree, y_train_tree)

print('Ein: %0.4f' % (1 - accuracy_score(y_train_tree, clf.predict(x_train_tree))))
print('Eout: %0.4f' % (1 - accuracy_score(y_test, clf.predict(x_test))))
print(classification_report(y_test, clf.predict(x_test)))
# Out:
# Ein: 0.1334
# Eout: 0.1341
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89       102
#            1       0.92      0.75      0.83        77
#
#     accuracy                           0.87       179
#    macro avg       0.88      0.85      0.86       179
# weighted avg       0.87      0.87      0.86       179

# %%
#codigo do professor 
# feature labels
features_label = x.columns

# class label
class_label = ['0','1']

plt.figure(figsize=(50,20))
plot_tree(
    clf, 
    feature_names = features_label,
    class_names = class_label, 
    filled=True, 
    proportion = True,
    fontsize=6, 
    rounded = True)

plt.savefig('arvore_podada.png')
plt.show()

# %% [markdown]
# # svm

# %%
model = SVC(kernel='linear')
model.fit(x_train, y_train)

print("#VS: " + str(model.n_support_))
print(model.support_vectors_)
# Out:
# #VS: [154 155]
# [[1.     0.     0.2625 0.    ]
#  [1.     1.     0.2    0.    ]
#  [0.     1.     0.35   0.    ]
#  ...
#  [1.     0.     0.35   0.    ]
#  [1.     0.     0.35   0.    ]
#  [1.     1.     0.3875 0.    ]]

# %%
svm_ = svm.SVC(kernel='rbf')

# Create the random grid
param_grid = {
              'C' : np.linspace(1,10,20),
              'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5] 
              }

CV_rf = GridSearchCV(estimator=svm_, param_grid=param_grid, cv = 5, verbose=2, n_jobs=-1)


# Fit the random search model
CV_rf.fit(x_train, y_train)

print(CV_rf.best_estimator_)
# print(CV_rf.best_params_)


print('Ein: %0.4f' % (1 - accuracy_score(y_train, CV_rf.predict(x_train))))
print('Eout: %0.4f' % (1 - accuracy_score(y_test, CV_rf.predict(x_test))))
print(classification_report(y_test, CV_rf.predict(x_test)))
# Out:
# Fitting 5 folds for each of 160 candidates, totalling 800 fits
# SVC(C=9.526315789473683, gamma=0.5)
# Ein: 0.1938
# Eout: 0.2011
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84       102
#            1       0.84      0.66      0.74        77
#
#     accuracy                           0.80       179
#    macro avg       0.81      0.78      0.79       179
# weighted avg       0.80      0.80      0.79       179
